# %% [markdown]
# ### Hands-on Lab: Build an Interactive Dashboard with Ploty Dash
# Rather than using the provided theiadocker instance that does not persist data, I am adapting the assignment to be run on jupyter notebook, original assignment instructions here: https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/lab_theia_plotly_dash.md.html - brt-h

# %%
# note that this notebook is not currently working correctly, there is a bug with the proxy config

# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in /home/suja/.local/lib/python3.10/site-packages (2.17.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/suja/.local/lib/python3.10/site-packages (from dash) (4.12.2)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/suja/.local/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: retrying in /home/suja/.local/lib/python3.10/site-packages (from dash) (1.3.4)
# Requirement already satisfied: requests in /home/suja/.local/lib/python3.10/site-packages (from dash) (2.32.3)
# Requirement already satisfied: dash-table==5.0.0 in /home/suja/.local/lib/python3.10/site-packages (from dash) (5.0.0)
# Requirement already satisfied: Werkzeug<3.1 in /home/suja/.local/lib/python3.10/site-packages (from dash) (3.0.4)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from dash) (4.6.4)
# Requirement already satisfied: nest-asyncio in /home/suja/.local/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from dash) (59.6.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/suja/.local/lib/python3.10/site-packages (from dash) (5.23.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/suja/.local/lib/python3.10/site-packages (from dash) (3.0.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/suja/.local/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: click>=8.1.3 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: packaging in /home/suja/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/suja/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/suja/.local/lib/python3.10/site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/suja/.local/lib/python3.10/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->dash) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->dash) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->dash) (2020.6.20)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->dash) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 KB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Flask>=1.0.4 in /home/suja/.local/lib/python3.10/site-packages (from dash==1.19.0) (3.0.3)
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 KB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.3 MB/s eta 0:00:004.5 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.5 MB/s eta 0:00:00m eta 0:00:010:01
#   Preparing metadata (setup.py) ... done
# Collecting flask-compress
#   Downloading Flask_Compress-1.15-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: plotly in /home/suja/.local/lib/python3.10/site-packages (from dash==1.19.0) (5.23.0)
# Requirement already satisfied: click>=8.1.3 in /home/suja/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/suja/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.4)
# Requirement already satisfied: blinker>=1.6.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.8.2)
# Collecting zstandard
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting brotli
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 6.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: tenacity>=6.2.0 in /home/suja/.local/lib/python3.10/site-packages (from plotly->dash==1.19.0) (9.0.0)
# Requirement already satisfied: packaging in /home/suja/.local/lib/python3.10/site-packages (from plotly->dash==1.19.0) (24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/suja/.local/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (2.1.5)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash_renderer, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84017 sha256=703392d27e9e4c05169811aa4c8f38a422288113f69589995e6241bf13085dce
#   Stored in directory: /home/suja/.cache/pip/wheels/63/5a/d3/e7c5d505ed098ea597b6be181fc3fd7c7c5477c343d54268e4
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527013 sha256=968703b5050f14ca0941d0c720ada3f2b75348df327f5f251fb14bfbaf99655b
#   Stored in directory: /home/suja/.cache/pip/wheels/e8/ae/61/827d67cc0e0c434785399fac7f8af8cee1bb9ff1d72604154c
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427845 sha256=a20cadbe860eb1b54b923328d8f6e8be7f00febe70020a5ac1ca7d2d37fa91f9
#   Stored in directory: /home/suja/.cache/pip/wheels/76/6b/5f/982ab99f663a59f2bfc42732003b936e24537e69a0d41bb11b
#   Building wheel for dash_renderer (setup.py) ... done
#   Created wheel for dash_renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014870 sha256=c9de24e274da62fb119f79623d8a638b13bf910169209275fd4aeb46d5112153
#   Stored in directory: /home/suja/.cache/pip/wheels/94/45/15/664379279493f60779ee1951944fff3ecf2d21598ff70b05b6
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839875 sha256=8b6b85cb9b6b3a5dd4d8e4306670239993eb4f917a9ec715e2a3226331aa5905
#   Stored in directory: /home/suja/.cache/pip/wheels/31/d8/bc/643db5bcce54a90a628224e8c0ce38dd3ccc576785d7f330ff
# Successfully built dash dash-core-components dash-html-components dash_renderer dash-table
# Installing collected packages: dash-table, dash_renderer, dash-html-components, dash-core-components, brotli, zstandard, flask-compress, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.17.1
#     Uninstalling dash-2.17.1:
#       Successfully uninstalled dash-2.17.1
# Successfully installed brotli-1.1.0 dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2 dash_renderer-1.9.0 flask-compress-1.15 zstandard-0.23.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (2.32.3)
# Collecting ansi2html
#   Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: retrying in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: flask in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: ipykernel in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (6.29.5)
# Requirement already satisfied: ipython in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (8.26.0)
# Requirement already satisfied: nest-asyncio in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: dash in /home/suja/.local/lib/python3.10/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: plotly in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (5.23.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: flask-compress in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (1.15)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/suja/.local/lib/python3.10/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/suja/.local/lib/python3.10/site-packages (from flask->jupyter_dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/suja/.local/lib/python3.10/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /home/suja/.local/lib/python3.10/site-packages (from flask->jupyter_dash) (1.8.2)
# Requirement already satisfied: click>=8.1.3 in /home/suja/.local/lib/python3.10/site-packages (from flask->jupyter_dash) (8.1.7)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/suja/.local/lib/python3.10/site-packages (from flask->jupyter_dash) (3.0.4)
# Requirement already satisfied: comm>=0.1.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: psutil in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (6.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (26.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (8.6.2)
# Requirement already satisfied: packaging in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (24.1)
# Requirement already satisfied: tornado>=6.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (1.8.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (0.19.1)
# Requirement already satisfied: stack-data in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (1.2.2)
# Requirement already satisfied: decorator in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (2.18.0)
# Requirement already satisfied: typing-extensions>=4.6 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (4.12.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter_dash) (3.0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/suja/.local/lib/python3.10/site-packages (from requests->jupyter_dash) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->jupyter_dash) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->jupyter_dash) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/suja/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/suja/.local/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/suja/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/suja/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.2.2)
# Requirement already satisfied: wcwidth in /home/suja/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /home/suja/.local/lib/python3.10/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /home/suja/.local/lib/python3.10/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/suja/.local/lib/python3.10/site-packages (from plotly->dash->jupyter_dash) (9.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter_dash) (2.4.1)
# Requirement already satisfied: pure-eval in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter_dash) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter_dash) (2.0.1)
# Installing collected packages: ansi2html, jupyter_dash
# Successfully installed ansi2html-1.9.2 jupyter_dash-0.4.2
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in /home/suja/.local/lib/python3.10/site-packages (5.23.0)
# Requirement already satisfied: packaging in /home/suja/.local/lib/python3.10/site-packages (from plotly) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/suja/.local/lib/python3.10/site-packages (from plotly) (9.0.0)

# %%
pip install --upgrade dash jupyter-dash
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in /home/suja/.local/lib/python3.10/site-packages (1.19.0)
# Collecting dash
#   Using cached dash-2.17.1-py3-none-any.whl (7.5 MB)
# Requirement already satisfied: jupyter-dash in /home/suja/.local/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: requests in /home/suja/.local/lib/python3.10/site-packages (from dash) (2.32.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from dash) (59.6.0)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/suja/.local/lib/python3.10/site-packages (from dash) (4.12.2)
# Requirement already satisfied: retrying in /home/suja/.local/lib/python3.10/site-packages (from dash) (1.3.4)
# Requirement already satisfied: plotly>=5.0.0 in /home/suja/.local/lib/python3.10/site-packages (from dash) (5.23.0)
# Requirement already satisfied: nest-asyncio in /home/suja/.local/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from dash) (4.6.4)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/suja/.local/lib/python3.10/site-packages (from dash) (3.0.3)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: Werkzeug<3.1 in /home/suja/.local/lib/python3.10/site-packages (from dash) (3.0.4)
# Requirement already satisfied: ipykernel in /home/suja/.local/lib/python3.10/site-packages (from jupyter-dash) (6.29.5)
# Requirement already satisfied: ansi2html in /home/suja/.local/lib/python3.10/site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: ipython in /home/suja/.local/lib/python3.10/site-packages (from jupyter-dash) (8.26.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: click>=8.1.3 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/suja/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/suja/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /home/suja/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/suja/.local/lib/python3.10/site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: pyzmq>=24 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (26.1.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: debugpy>=1.6.5 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (1.8.5)
# Requirement already satisfied: comm>=0.1.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (0.2.2)
# Requirement already satisfied: psutil in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (6.0.0)
# Requirement already satisfied: tornado>=6.1 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/suja/.local/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (8.6.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (2.18.0)
# Requirement already satisfied: jedi>=0.16 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (0.19.1)
# Requirement already satisfied: stack-data in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (3.0.47)
# Requirement already satisfied: decorator in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/suja/.local/lib/python3.10/site-packages (from ipython->jupyter-dash) (1.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->dash) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->dash) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->dash) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/suja/.local/lib/python3.10/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/suja/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/suja/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/suja/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.2.2)
# Requirement already satisfied: wcwidth in /home/suja/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: pure-eval in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/suja/.local/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash) (2.4.1)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 4.11.2
#     Uninstalling dash-table-4.11.2:
#       Successfully uninstalled dash-table-4.11.2
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 1.1.2
#     Uninstalling dash-html-components-1.1.2:
#       Successfully uninstalled dash-html-components-1.1.2
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 1.15.0
#     Uninstalling dash-core-components-1.15.0:
#       Successfully uninstalled dash-core-components-1.15.0
#   Attempting uninstall: dash
#     Found existing installation: dash 1.19.0
#     Uninstalling dash-1.19.0:
#       Successfully uninstalled dash-1.19.0
# Successfully installed dash-2.17.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install werkzeug==2.0.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting werkzeug==2.0.3
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 KB 1.7 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# Installing collected packages: werkzeug
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.4
#     Uninstalling Werkzeug-3.0.4:
#       Successfully uninstalled Werkzeug-3.0.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.0.3 requires Werkzeug>=3.0.0, but you have werkzeug 2.0.3 which is incompatible.
# Successfully installed werkzeug-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# /tmp/ipykernel_9602/2314399724.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# /tmp/ipykernel_9602/2314399724.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ----------------
# ansi2html                 1.9.2
# anyio                     4.4.0
# apturl                    0.5.2
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# bcrypt                    3.2.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.8.2
# branca                    0.7.2
# Brlapi                    0.8.3
# Brotli                    1.1.0
# bs4                       0.0.2
# certifi                   2020.6.20
# cffi                      1.17.0
# chardet                   4.0.0
# charset-normalizer        3.3.2
# click                     8.1.7
# colorama                  0.4.4
# comm                      0.2.2
# command-not-found         0.3
# contourpy                 1.2.1
# cryptography              3.4.8
# cupshelpers               1.0
# cycler                    0.12.1
# dash                      2.17.1
# dash-core-components      2.0.0
# dash-html-components      2.0.0
# dash-renderer             1.9.0
# dash-table                5.0.0
# dbus-python               1.2.18
# debugpy                   1.8.5
# decorator                 5.1.1
# defer                     1.0.6
# defusedxml                0.7.1
# distro                    1.7.0
# distro-info               1.1+ubuntu0.2
# duplicity                 0.8.21
# exceptiongroup            1.2.2
# executing                 2.0.1
# fasteners                 0.14.1
# fastjsonschema            2.20.0
# Flask                     3.0.3
# Flask-Compress            1.15
# folium                    0.17.0
# fonttools                 4.53.1
# fqdn                      1.5.1
# frozendict                2.4.4
# future                    0.18.2
# h11                       0.14.0
# html5lib                  1.1
# httpcore                  1.0.5
# httplib2                  0.20.2
# httpx                     0.27.0
# idna                      3.3
# importlib-metadata        4.6.4
# ipykernel                 6.29.5
# ipython                   8.26.0
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.1
# jeepney                   0.7.1
# Jinja2                    3.1.4
# joblib                    1.4.2
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.2
# jupyter_core              5.7.2
# jupyter-dash              0.4.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# keyring                   23.5.0
# kiwisolver                1.4.5
# language-selector         0.1
# launchpadlib              1.10.16
# lazr.restfulclient        0.14.4
# lazr.uri                  1.0.6
# lockfile                  0.12.2
# louis                     3.20.0
# lxml                      5.3.0
# macaroonbakery            1.3.1
# Mako                      1.1.3
# MarkupSafe                2.1.5
# matplotlib                3.9.2
# matplotlib-inline         0.1.7
# meson                     1.5.1
# mistune                   3.0.2
# monotonic                 1.6
# more-itertools            8.10.0
# multitasking              0.0.11
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# netifaces                 0.11.0
# ninja                     1.11.1.1
# notebook                  7.2.1
# notebook_shim             0.2.4
# numpy                     2.0.1
# oauthlib                  3.2.0
# olefile                   0.46
# opencv-contrib-python     4.10.0.84
# overrides                 7.7.0
# packaging                 24.1
# pandas                    2.2.2
# pandocfilters             1.5.1
# paramiko                  2.9.3
# parso                     0.8.4
# peewee                    3.17.6
# pexpect                   4.8.0
# Pillow                    9.0.1
# pip                       22.0.2
# platformdirs              4.2.2
# plotly                    5.23.0
# prometheus_client         0.20.0
# prompt_toolkit            3.0.47
# protobuf                  3.12.4
# psutil                    6.0.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycairo                   1.20.1
# pycparser                 2.22
# pycups                    2.0.1
# pyds                      0.2.0
# Pygments                  2.18.0
# PyGObject                 3.42.1
# PyJWT                     2.3.0
# pymacaroons               0.13.0
# PyNaCl                    1.5.0
# pyparsing                 2.4.7
# pyRFC3339                 1.1
# python-apt                2.4.0+ubuntu3
# python-dateutil           2.9.0.post0
# python-debian             0.1.43+ubuntu1.1
# python-json-logger        2.0.7
# pytz                      2024.1
# pyxdg                     0.27
# PyYAML                    5.4.1
# pyzmq                     26.1.1
# referencing               0.35.1
# reportlab                 3.6.8
# requests                  2.32.3
# retrying                  1.3.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.20.0
# scikit-learn              1.5.1
# scipy                     1.14.1
# screen-resolution-extra   0.0.0
# seaborn                   0.13.2
# SecretStorage             3.3.1
# Send2Trash                1.8.3
# setuptools                59.6.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# systemd-python            234
# tenacity                  9.0.0
# terminado                 0.18.1
# threadpoolctl             3.5.0
# tinycss2                  1.3.0
# tomli                     2.0.1
# tornado                   6.4.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# typing_extensions         4.12.2
# tzdata                    2024.1
# ubuntu-drivers-common     0.0.0
# ubuntu-pro-client         8001
# ufw                       0.36.1
# unattended-upgrades       0.1
# uri-template              1.3.0
# urllib3                   1.26.5
# usb-creator               0.3.7
# wadllib                   1.3.6
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  2.0.3
# wget                      3.2
# wheel                     0.37.1
# xdg                       5
# xkit                      0.0.0
# xyzservices               2024.6.0
# yfinance                  0.2.42
# zipp                      1.0.0
# zstandard                 0.23.0

# %%
# !jupyter labextension list

# %%
# notebook hangs if I run the following command 
JupyterDash.infer_jupyter_proxy_config()

# %%
# needs to be run again in a separate cell due to a jupyterdash bug
JupyterDash.infer_jupyter_proxy_config()

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
